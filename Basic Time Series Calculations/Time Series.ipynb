# %%
#Install Pandas-Data Reader

pip install pandas-datareader

# %%
# !pip install yfinance

# %%
# !pip install fix_yahoo_finance

# %%
# %%time
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

import fix_yahoo_finance
# Out:
# Wall time: 0 ns

# %%
# %%time

import yfinance as yf
df_tesla = yf.download('TSLA')
df_tesla
# Out:
# [*********************100%***********************]  1 of 1 completed
# Wall time: 880 ms
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-04-19  179.100006  183.500000  177.649994  180.589996  180.589996
# 2023-04-20  166.169998  169.699997  160.559998  162.990005  162.990005
# 2023-04-21  164.800003  166.000000  161.320007  165.080002  165.080002
# 2023-04-24  164.649994  165.649994  158.610001  162.550003  162.550003
# 2023-04-25  159.820007  163.470001  158.750000  160.669998  160.669998
#
# ...

# %%
df_tesla.shape
# Out:
# (3228, 6)

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# X Limit and Y Limit
df_tesla['High'].plot(xlim=['2020-01-01','2022-01-01'],ylim=[0,500],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2022-01-01'],ylim=[0,500],figsize=(12,4),color='green',ls='--')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-04-12', '2023-04-13', '2023-04-14', '2023-04-17',
#                '2023-04-18', '2023-04-19', '2023-04-20', '2023-04-21',
#                '2023-04-24', '2023-04-25'],
#               dtype='datetime64[ns]', name='Date', length=3228, freq=None)

# %%
index = df_tesla.loc['2020-01-01':'2021-09-01'].index 
share_open = df_tesla.loc['2020-01-01':'2021-09-01'] ["Open"]
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure , axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
#DateTime Index

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3228 entries, 2010-06-29 to 2023-04-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3228 non-null   float64
#  1   High       3228 non-null   float64
#  2   Low        3228 non-null   float64
#  3   Close      3228 non-null   float64
#  4   Adj Close  3228 non-null   float64
#  5   Volume     3228 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 305.6 KB

# %%
df_tesla = df_tesla.reset_index()
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3223 2023-04-19  179.100006  183.500000  177.649994  180.589996  180.589996
# 3224 2023-04-20  166.169998  169.699997  160.559998  162.990005  162.990005
# 3225 2023-04-21  164.800003  166.000000  161.320007  165.080002  165.080002
# 3226 2023-04-24  164.649994  165.649994  158.610001  162.550003  162.550003
# 3227 2023-04-25  159.820007  163.470001  158.750000  160.669998  160.669998
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3228 non-null   datetime64[ns]
#  1   Open       3228 non-null   float64
#  2   High       3228 non-null   float64
#  3   Low        3228 non-null   float64
#  4   Close      3228 non-null   float64
#  5   Adj Close  3228 non-null   float64
#  6   Volume     3228 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 176.7 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3223   2023-04-19
# 3224   2023-04-20
# 3225   2023-04-21
# 3226   2023-04-24
# 3227   2023-04-25
# Name: Date, Length: 3228, dtype: datetime64[ns]

# %%
df_tesla.set_index('Date',inplace=True,drop=True)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-04-19  179.100006  183.500000  177.649994  180.589996  180.589996
# 2023-04-20  166.169998  169.699997  160.559998  162.990005  162.990005
# 2023-04-21  164.800003  166.000000  161.320007  165.080002  165.080002
# 2023-04-24  164.649994  165.649994  158.610001  162.550003  162.550003
# 2023-04-25  159.820007  163.470001  158.750000  160.669998  160.669998
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
## datetime

from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 26, 21, 6, 42, 830519)

# %%
date = datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %%
## Time Resampling

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
type(df_tesla.resample(rule='A').max())
# Out:
# pandas.core.frame.DataFrame

# %%
# Year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Quartely end frequency
df_tesla.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.tight_layout()
df_tesla.iloc[:1209,:1].resample(rule='M').mean().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Rolling

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
df_tesla['Open:30 Days rolling'] = df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 Days rolling
# Date
# 2010-06-29                   NaN
# 2010-06-30                   NaN
# 2010-07-01                   NaN
# 2010-07-02                   NaN
# 2010-07-06                   NaN

# %%
df_tesla[['Open','Open:30 Days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>
